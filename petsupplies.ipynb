# %%
# Importing all necessarry packages

import pandas as pd
import numpy as np


from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

import nltk

from sklearn.feature_extraction.text import TfidfVectorizer


from sklearn import preprocessing


from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc

# %%
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield eval(l)

import json
import gzip

def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield json.dumps(eval(l))

f = open("output.strict", 'w')
for l in parse(r"C:\Users\rithv\Desktop\paper\reviews_Pet_Supplies_5.json.gz"):
    f.write(l + '\n')

import pandas as pd
import gzip

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

df = getDF(r'C:\Users\rithv\Desktop\paper\reviews_Pet_Supplies_5.json.gz')

# %%
df.head(10)
# Out:
#        reviewerID        asin           reviewerName   helpful  \
# 0  A14CK12J7C7JRK  1223000893     Consumer in NorCal    [0, 0]
# 1  A39QHP5WLON5HV  1223000893        Melodee Placial    [0, 0]
# 2  A2CR37UY3VR7BN  1223000893       Michelle Ashbery    [0, 0]
# 3  A2A4COGL9VW2HY  1223000893             Michelle P    [2, 2]
# 4  A2UBQA85NIGLHA  1223000893  Tim  Isenhour "Timbo"    [6, 7]
# 5  A2V3UP9NPMHVKJ  4847676011    Alex Thomas "Tommy"  [10, 10]
# 6  A2R4JCEFLTFU8F  4847676011       goldilox "goldi"    [2, 2]
# 7  A14B4MJ7KZE63B  4847676011                K Young    [2, 2]
# 8  A2JDB26Y78TT8Z  4847676011     L. Miller "LMinGA"    [0, 0]
# 9   A8GY0E0SS8VMD  4847676011                 Wolves    [1, 1]
#
#                                           reviewText  overall  \
# 0  I purchased the Trilogy with hoping my two cat...      3.0
# 1  There are usually one or more of my cats watch...      5.0
# 2  I bought the triliogy and have tested out all ...      4.0
# ...

# %%
df.tail(10)
# Out:
#             reviewerID        asin                               reviewerName  \
# 157826  A3NHUQ33CFH3VM  B00KMHKOZC                               Citizen John
# 157827  A3VBXQKRM7A4JR  B00KMHKOZC                                    eyecore
# 157828  A13H5US9Z7L9M7  B00KMHKOZC                                   K.Wagner
# 157829  A31RULW0KNYJ5H  B00KMHKOZC                                         LA
# 157830   AAA0TUKS5VBSA  B00KMHKOZC                                 Nerd Alert
# 157831  A136YD08SCJ2LV  B00KMHKOZC                         R. Spell "raspell"
# 157832  A2YKWYC3WQJX5J  B00KMHKOZC      Shannon Lastowski "Queen of Caffeine"
# 157833  A2K0D19N83G6U2  B00KMHKOZC              Spoiled Rott'n "Maria Olipas"
# 157834  A3A4ZAIBQWKOZS  B00KMHKOZC                           Stephen M. Lerch
# 157835  A1ITRGMT80D5TK  B00KMHKOZC  ThisThatNEverything "thisthatneverything"
#
#        helpful                                         reviewText  overall  \
# ...

# %%
df.describe()
# Out:
#              overall  unixReviewTime
# count  157836.000000    1.578360e+05
# mean        4.229745    1.363741e+09
# std         1.175819    3.877432e+07
# min         1.000000    1.009757e+09
# 25%         4.000000    1.353629e+09
# 50%         5.000000    1.373846e+09
# 75%         5.000000    1.390176e+09
# max         5.000000    1.406074e+09

# %%
df.size
# Out:
# 1420524

# %%
df.shape
# Out:
# (157836, 9)

# %%
df_use=df[['overall','summary']]

# %%
print (df_use.head(10))
print(df_use.tail(10))
# Out:
#    overall                                            summary
# 0      3.0  Nice Distraction for my cats for about 15 minutes
# 1      5.0                           Entertaining for my cats
# 2      4.0                                       Entertaining
# 3      4.0                                 Happy to have them
# 4      3.0                         You really only need vol 2
# 5      5.0                 Great for Pups with Food Allergies
# 6      5.0                                   Naturally Yummy!
# 7      4.0                     bought to help with dog breath
# 8      5.0  Brushing those teeth isn't so hard with this d...
# 9      5.0                                   Good product ...
#         overall                                            summary
# 157826      5.0                     Comfortable, ergonomic design.
# 157827      5.0                                   Great dog leash!
# 157828      4.0       This company makes good, dependable products
# ...

# %%
#df_use.isna()

# %%
#mean of overall rating 
sum(df_use.overall)/len(df_use.overall)
# Out:
# 4.229744798398338

# %%
#df_use.groupby('overall').describe()

# %%
#df_df=pd.DataFrame(df_use)
#df_df.head()

# %%
for i in range(len(df_use)):
    print(df_use.overall[i]==2)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# True
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# ...

# %%
result = [] 
for value in df_use["overall"]: 
    if value == 1.0: 
        result.append("Negative") 
    elif value==2.0: 
        result.append("Negative") 
    elif value==3.0: 
        result.append("Neutral")
    elif value==4.0: 
        result.append("Positive")
    elif value==5.0: 
        result.append("Positive")
       
df_use["Result"] = result
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_use.head()
# Out:
#    overall                                            summary    Result
# 0      3.0  Nice Distraction for my cats for about 15 minutes   Neutral
# 1      5.0                           Entertaining for my cats  Positive
# 2      4.0                                       Entertaining  Positive
# 3      4.0                                 Happy to have them  Positive
# 4      3.0                         You really only need vol 2   Neutral

# %%
df_filtered=df_use.loc[df_use['Result']!='Neutral']
df_filtered.tail(20)
# Out:
#         overall                                            summary    Result
# 157816      5.0                                      Cat approves!  Positive
# 157817      5.0                                      Nice product!  Positive
# 157818      5.0                                         I Love it!  Positive
# 157819      5.0           Our dogs love getting brushed with this.  Positive
# 157820      5.0                                       Pets Approve  Positive
# 157821      5.0                   Well worth my time and purchase.  Positive
# 157822      5.0                     A great product that works!!!!  Positive
# 157823      5.0                                        Time Saver!  Positive
# 157824      5.0                                         I love it!  Positive
# 157825      5.0  No wonder this is the #1 selling dog leash on ...  Positive
# 157826      5.0                     Comfortable, ergonomic design.  Positive
# ...

# %%
df_use=df_filtered

# %%
df_use.groupby('Result').describe()
# Out:
#            overall
#              count      mean       std  min  25%  50%  75%  max
# Result
# Negative   17655.0  1.504503  0.499994  1.0  1.0  2.0  2.0  2.0
# Positive  124248.0  4.774685  0.417792  4.0  5.0  5.0  5.0  5.0

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(8,8))
sns.countplot(df_use['Result'])
plt.show()

# %%
#df_use['length']=df_use['summary'].apply(len)

# %%
#df_use.head()

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
import nltk 
nltk.download('stopwords')
import string 
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rithv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords_json = pd.read_json(r"https://raw.githubusercontent.com/6/stopwords-json/master/dist/en.json" )
stopwords_json.head(3)
# Out:
#       0
# 0     a
# 1   a's
# 2  able

# %%
stopwords_json.columns = ["en"]
'''stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])'''
# Out:
# 'stopwords= set([\'br\', \'the\', \'i\', \'me\', \'my\', \'myself\', \'we\', \'our\', \'ours\', \'ourselves\', \'you\', "you\'re", "you\'ve",            "you\'ll", "you\'d", \'your\', \'yours\', \'yourself\', \'yourselves\', \'he\', \'him\', \'his\', \'himself\',             \'she\', "she\'s", \'her\', \'hers\', \'herself\', \'it\', "it\'s", \'its\', \'itself\', \'they\', \'them\', \'their\',            \'theirs\', \'themselves\', \'what\', \'which\', \'who\', \'whom\', \'this\', \'that\', "that\'ll", \'these\', \'those\',             \'am\', \'is\', \'are\', \'was\', \'were\', \'be\', \'been\', \'being\', \'have\', \'has\', \'had\', \'having\', \'do\', \'does\',             \'did\', \'doing\', \'a\', \'an\', \'the\', \'and\', \'but\', \'if\', \'or\', \'because\', \'as\', \'until\', \'while\', \'of\',             \'at\', \'by\', \'for\', \'with\', \'about\', \'against\', \'between\', \'into\', \'through\', \'during\', \'before\', \'after\',            \'above\', \'below\', \'to\', \'
# ...

# %%
x = stopwords.words("english")
x
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
stopwords_json_en = set(stopwords_json['en'])
stopwords_nltk_en = set(x)
stoplist_combined = set.union(stopwords_json_en, stopwords_nltk_en)

# %%
import re
from tqdm import tqdm
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
def cleanup_text(msg):
    No_Punctuation = [char for char in msg if char not in string.punctuation]
    sentance = ''.join(No_Punctuation) #joins all the strings
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    return [word.lower() for word in sentance.split() if word.lower() not in stoplist_combined]

# %%
from bs4 import BeautifulSoup

# %%
df_use['message'] = df_use['summary'].apply(cleanup_text)

# %%
df_use.head(20)
# Out:
#     overall                                            summary    Result  \
# 1       5.0                           Entertaining for my cats  Positive
# 2       4.0                                       Entertaining  Positive
# 3       4.0                                 Happy to have them  Positive
# 5       5.0                 Great for Pups with Food Allergies  Positive
# 6       5.0                                   Naturally Yummy!  Positive
# 7       4.0                     bought to help with dog breath  Positive
# 8       5.0  Brushing those teeth isn't so hard with this d...  Positive
# 9       5.0                                   Good product ...  Positive
# 10      2.0                         my puppy wont eat his food  Negative
# 11      1.0             Didn't work and the smell is sickening  Negative
# 13      4.0                                      Mixed Results  Positive
# 14      1.0                                      does not work  Negative
# ...

# %%
#df_use.tail(20)

# %%
#type(df_use['message'][0])

# %%
#df_use.head(20)

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
y = df_use.Result
X = df_use.drop(['Result','summary','overall'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)
X = pd.concat([X_train, y_train], axis=1)
not_fraud = X[X.Result=='Positive']
fraud = X[X.Result=='Negative']
fraud_upsampled = resample(fraud,replace=True,n_samples=len(not_fraud), random_state=27) 
upsampled = pd.concat([not_fraud, fraud_upsampled])
#upsampled.Result.value_counts()  # To check sampled values

# %%
upsampled
# Out:
#                                                   message    Result
# 99647                           [great, item, cat, loves]  Positive
# 98869                                      [simple, made]  Positive
# 153255  [wont, buying, big, names, anymorei, found, in...  Positive
# 67595                                     [works, pricey]  Positive
# 116049                                           [shadow]  Positive
# ...                                                   ...       ...
# 108075                                            [stars]  Negative
# 61729                                    [piece, garbage]  Negative
# 114139                                     [crazy, price]  Negative
# 33987             [small, means, small, dogs, eat, quick]  Negative
# 109551                                           [speeds]  Negative
#
# [186242 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(7,7))
sns.countplot(upsampled['Result'])
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(upsampled['message'], upsampled['Result'], test_size=0.25 )

# %%
#Converting positive / Negetive labels to 1/0

encoder = preprocessing.LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test  = encoder.fit_transform(y_test)

# %%
# Checking size of training and testing samples
print(y_test.shape)
print(y_train.shape)
print(X_test.shape)
print(X_train.shape)
# Out:
# (46561,)
# (139681,)
# (46561,)
# (139681,)

# %%
y_test
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
tfidf_vect = TfidfVectorizer(analyzer='word',  token_pattern=r'\w{2,}', max_features=5000, lowercase=False)

# %%
tfidf_fit_tra = tfidf_vect.fit_transform(X_train).toarray() # Fit-transform of Train data
tfidf_fit_tra
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-8c7ca909828b> in <module>
# ----> 1 tfidf_fit_tra = tfidf_vect.fit_transform(X_train).toarray() # Fit-transform of Train data
#       2 tfidf_fit_tra
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1650         """
#    1651         self._check_params()
# -> 1652         X = super().fit_transform(raw_documents)
#    1653         self._tfidf.fit(X)
#    1654         # X is already a transformed view of raw_documents so
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ...

# %%
#tfidf_fit_tra = tfidf_fit_tra.toarray()

# %%
logreg=LogisticRegression()

y_train=y_train.astype('int')            # converting to int

logreg.fit(tfidf_fit_tra, y_train)       #Fitting Logistic Regression on Training data

tfidf_fit_tra_test=tfidf_vect.fit_transform(X_test)   # Transforming Test data according to TF-IDF fit

y_pred = logreg.predict(tfidf_fit_tra_test)          #Predicting values on test dataset
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-4659f3d27b6c> in <module>
#       3 y_train=y_train.astype('int')            # converting to int
#       4
# ----> 5 logreg.fit(tfidf_fit_tra, y_train)       #Fitting Logistic Regression on Training data
#       6
#       7 tfidf_fit_tra_test=tfidf_vect.fit_transform(X_test)   # Transforming Test data according to TF-IDF fit
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# ...

# %%
# Checking predicted and actual

print(y_pred[80])
print(y_test[80])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-8295babce9af> in <module>
#       1 # Checking predicted and actual
#       2
# ----> 3 print(y_pred[80])
#       4 print(y_test[80])
#
# NameError: name 'y_pred' is not defined

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-154-eb27c3a21518> in <module>
# ----> 1 metrics.accuracy_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-430e012b2078> in <module>
# ----> 1 confusion_matrix(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-e7622b950e3d> in <module>
# ----> 1 print(classification_report(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
mnb = MultinomialNB()

mnb.fit(tfidf_fit_tra, y_train)

y_pred = mnb.predict(tfidf_fit_tra_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-01be27e402c7> in <module>
#       1 mnb = MultinomialNB()
#       2
# ----> 3 mnb.fit(tfidf_fit_tra, y_train)
#       4
#       5 y_pred = mnb.predict(tfidf_fit_tra_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     586         self : object
#     587         """
# --> 588         X, y = check_X_y(X, y, 'csr')
#     589         _, n_features = X.shape
#     590
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     727         y = y.astype(np.float64)
#     728
# --> 729     check_consistent_length(X, y)
#     730
# ...

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-eb27c3a21518> in <module>
# ----> 1 metrics.accuracy_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
confusion_matrix(y_test, y_pred)

# %%
print(classification_report(y_test, y_pred))

# %%
from sklearn.model_selection import train_test_split
Z=df_use.drop("summary",1)
#Z1=Z.drop("length",1)
Z2=Z.drop("overall",1)
X=Z2.drop("Result",1)

Y= Z2.drop("message",1)

# %%
#Y=Y.set_index('Result')

# %%
#X=X.set_index('message')

# %%
X.head()
# Out:
#                           message
# 1            [entertaining, cats]
# 2                  [entertaining]
# 3                         [happy]
# 5  [great, pups, food, allergies]
# 6              [naturally, yummy]

# %%
Y.head()
# Out:
#      Result
# 1  Positive
# 2  Positive
# 3  Positive
# 5  Positive
# 6  Positive

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (106427, 1)
# (35476, 1)
# (106427, 1)
# (35476, 1)

# %%
X_test.head()
# Out:
#                     message
# 119601                [big]
# 30066      [designed, cats]
# 119083      [dogs, control]
# 20481   [highly, recommend]
# 2613                 [good]

# %%
X_train
# Out:
#                                         message
# 64956                               [cat, food]
# 48743                  [couldnt, pill, pockets]
# 19222                             [litter, box]
# 111068       [excellent, keeping, mess, ground]
# 129412                 [alpine, cat, scratcher]
# ...                                         ...
# 113290  [solid, chew, toy, aggressive, chewers]
# 116964                           [great, leash]
# 109876                                [awesome]
# 373                                [great, toy]
# 146752            [quartered, halved, pictured]
#
# [106427 rows x 1 columns]

# %%
bag_of_words = CountVectorizer(analyzer=cleanup_text).fit(X_train['message'])
print(bag_of_words)
# Out:
# CountVectorizer(analyzer=<function cleanup_text at 0x000002371405B288>,
#                 binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
message_bagofwords = bag_of_words.transform(X_train['message'])
print(message_bagofwords)
# Out:
#   (0, 5201)	1
#   (1, 9088)	1
#   (2, 35078)	1
#   (3, 16135)	1
#   (4, 617)	1
#   (5, 54954)	1
#   (6, 25440)	1
#   (7, 48609)	1
#   (8, 16330)	1
#   (9, 37597)	1
#   (10, 16665)	1
#   (11, 3553)	1
#   (12, 36792)	1
#   (13, 1660)	1
#   (14, 17400)	1
#   (15, 29822)	1
#   (16, 57807)	1
#   (17, 52042)	1
#   (18, 14201)	1
#   (19, 11153)	1
#   (20, 33950)	1
#   (21, 56973)	1
#   (22, 649)	1
#   (24, 20452)	1
#   (25, 6957)	1
#   :	:
#   (106402, 49344)	1
#   (106403, 5613)	1
#   (106404, 23473)	1
#   (106405, 24978)	1
#   (106406, 34640)	1
#   (106407, 12726)	1
#   (106408, 50659)	1
#   (106409, 5830)	1
#   (106410, 46201)	1
#   (106411, 3188)	1
#   (106412, 33568)	1
#   (106413, 21506)	1
#   (106414, 46933)	1
#   (106415, 19044)	1
#   (106416, 25198)	1
#   (106417, 17080)	1
#   (106418, 28166)	1
#   (106419, 39041)	1
#   (106420, 1471)	1
#   (106421, 50659)	1
#   (106422, 50005)	1
#   (106423, 26203)	1
#   (106424, 1471)	1
#   (106425, 28487)	1
#   (106426, 45993)	1

# %%
print("some feature names ", bag_of_words.get_feature_names()[:])
print("the type of count vectorizer ",type(message_bagofwords))
print("the shape of out text BOW vectorizer ",message_bagofwords.get_shape())
print("the number of unique words ", message_bagofwords.get_shape()[1])
# Out:
# some feature names  ['aaaaaaaaaaaa', 'aaaarghfindflavorcatlikes', 'aaapetbag', 'aaarfaarfaarfffheloves', 'abandoncatlove', 'abbeylovesthings', 'abby', 'abbynormalcatsgivepaws', 'abilitybuycase', 'abogeardogdigspetcrate', 'abogearhappyhabitat', 'abolistens', 'abosorbent', 'abrasive', 'absolute', 'absolutebigtimedisappointing', 'absolutebomb', 'absolutechoisecathotspots', 'absolutecleaner', 'absolutecrap', 'absolutecrittertrailhabitats', 'absolutefavoritetoy', 'absolutefishtanks', 'absolutegroomingsupplyinventory', 'absolutehit', 'absolutehomemadedogfood', 'absoluteinteractivetoycat', 'absolutejoy', 'absolutelifesaver', 'absolutelifesavers', 'absolutelovebag', 'absolutely', 'absolutelyadorable', 'absolutelyadorecups', 'absolutelyamazed', 'absolutelyamazing', 'absolutelyamazingkindbulky', 'absolutelyamazingnoticeablechange', 'absolutelyamazingproduct', 'absolutelyawesome', 'absolutelyawesomecattree', 'absolutelyawesomesturdycage', 'absolutelyawfulcatfood', 'absolutelycatlitterscoop', 'a
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
# Out:
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text BOW vectorizer  (106427, 58908)
# the number of unique words  58908

# %%
tfidf_transformer = TfidfTransformer().fit(message_bagofwords)
print(tfidf_transformer)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
message_tfidf= tfidf_transformer.transform(message_bagofwords)

# %%
#print(message_tfidf)

# %%
message_tfidf.shape
# Out:
# (106427, 58908)

# %%
#Y_train.shape

# %%
#Y_train[5]

# %%
message_tfidf.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-73-0386f474d6a8> in <module>
# ----> 1 message_tfidf.toarray()
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1026             raise ValueError('Output array must be C or F contiguous')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1184             return out
#    1185         else:
# -> 1186             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1187
#    1188
#
# MemoryError:

# %%
#[message_tfidf[0,i] for i in range(message_tfidf.shape[1]) if message_tfidf[0,i]!=0]

# %%
'''from sklearn.naive_bayes import MultinomialNB
sentiment_detection_model = MultinomialNB().fit(message_tfidf,Y_train)'''
# Out:
# 'from sklearn.naive_bayes import MultinomialNB\nsentiment_detection_model = MultinomialNB().fit(message_tfidf,Y_train)'

# %%
'''comment = df_use['message'][1245]
bag_of_words_for_message = bag_of_words.transform(['message'])
tfidf = tfidf_transformer.transform(bag_of_words_for_message)

print('predicted sentiment label ', sentiment_detection_model.predict(tfidf)[0])
print ('expected sentiment label', Y_train[1245])'''
# Out:
# "comment = df_use['message'][1245]\nbag_of_words_for_message = bag_of_words.transform(['message'])\ntfidf = tfidf_transformer.transform(bag_of_words_for_message)\n\nprint('predicted sentiment label ', sentiment_detection_model.predict(tfidf)[0])\nprint ('expected sentiment label', Y_train[1245])"

# %%
#print(sentiment_detection_model.score)

# %%
#message_tfidf.shape

# %%
#predict = sentiment_detection_model.predict(tfidf)

# %%
from sklearn.linear_model import LogisticRegression

# %%
Log_reg=LogisticRegression()

# %%
model=Log_reg.fit(message_tfidf,Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
comment=df_use['message'][17]
bag_of_words_for_comment = bag_of_words.transform([comment])
tfidf = tfidf_transformer.transform(bag_of_words_for_comment)

print('predicted sentiment label ', model.predict(tfidf)[0])
print ('expected sentiment label', df_use.Result[17])
# Out:
# predicted sentiment label  Positive
# expected sentiment label Positive
